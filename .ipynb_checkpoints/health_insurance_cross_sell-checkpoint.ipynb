# %% [markdown]
# # 0.0 HELPER FUNCTIONS & IMPORTS

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import scikitplot as skplt
import boruta as bt
import pickle
import xgboost as xgb
import warnings
import random
import psycopg2
import config as creds


from IPython.display import Image
from IPython.core.display import HTML
from matplotlib import pyplot as plt
from scipy import stats
from sklearn import preprocessing as pp
from sklearn import model_selection as ms
from sklearn import ensemble as en
from sklearn import neighbors as nh
from sklearn import linear_model as lm
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.model_selection import StratifiedShuffleSplit as ss
from sklearn.metrics import f1_score
from tabulate import tabulate

# %% [markdown]
# ## Functions

# %%
# Funções

def connect():

    # set up a connection to the postgres server.
    conn_string = ("host="+ creds.PGHOST +\
                   " port="+ "5432" +\
                   " dbname="+ creds.PGDATABASE +\
                   " user=" + creds.PGUSER+ \
                   " password="+ creds.PGPASSWORD)
    
    conn = psycopg2.connect(conn_string)

    # create a cursor object
    # used to perform queries
    cursor = conn.cursor()
    
    return conn, cursor




def jupyter_settings():
    
    
    plt.style.use( 'bmh' )
    plt.rcParams['figure.figsize'] = [25, 12]
    plt.rcParams['font.size'] = 24
   

    display( HTML( '<style>.container { width:80% !important; }</style>') )
    pd.options.display.max_columns = None
    pd.options.display.max_rows = None
    pd.set_option( 'display.expand_frame_repr', False )
    
    sns.set()
    
def cramer_v( x, y ):
    cm = pd.crosstab( x, y ).to_numpy()
    n = cm.sum()
    r, k = cm.shape

    chi2 = stats.chi2_contingency( cm )[0]
    chi2corr = max( 0, chi2 - (k-1)*(r-1)/(n-1) )

    kcorr = k - (k-1)**2/(n-1)
    rcorr = r - (r-1)**2/(n-1)
    return np.sqrt( (chi2corr/n) / ( min( kcorr-1, rcorr-1 ) ) )




def concat_order_data( x_val, y_val, yhat ):
    
    # copy data
    data = x_val.copy()
    data['response'] = y_val.copy()

    # propensity score
    data['score'] = yhat[:, 1].tolist()

    # sorted clients by propensity score
    data = data.sort_values( 'score', ascending=False )
    
    return data




def precision_at_k( data, k=20000 ):
    
    # Reset Index
    data = data.reset_index(drop=True)

    # Create ranking order
    data['ranking'] = data.index + 1

    data['precision_at_k'] = data['response'].cumsum() / data['ranking']
    
    return data.loc[k, 'precision_at_k']



def recall_at_k( data, k=20000 ):
    
    # Reset Index
    data = data.reset_index(drop=True)

    # Create ranking order
    data['ranking'] = data.index + 1

    data['recall_at_k'] = data['response'].cumsum() / data['response'].sum()
    
    return data.loc[k, 'recall_at_k']




def at_k_metrics( model_name, x_val, y_val, yhat, k=20000 ):
    
    data = concat_order_data( x_val, y_val, yhat )
    
    pr = precision_at_k( data, k )
    re = recall_at_k( data, k )
    
    return pd.DataFrame({"Precision_at_k": "{}".format(np.round(pr,3) ),
                         "Recall_at_k": "{}".format( np.round(re,3) ) }, index=[model_name])



def cross_validation(model_name, model, x_train, y_train, k=20000 ):
    
    precision_at_k_list = []
    recall_at_k_list = []

    skf = ms.StratifiedKFold(n_splits=5, shuffle=True, random_state=5)
    
    for train_index, test_index in skf.split(x_train, y_train):
        
        x_train_cv = x_train.iloc[train_index]
        y_train_cv = y_train.iloc[train_index]
        
        x_test_cv = x_train.iloc[test_index]
        y_test_cv = y_train.iloc[test_index]
        
        # model training
        model.fit(x_train_cv, y_train_cv)
        
        # prediction
        pred = model.predict_proba(x_test_cv)
        
        # concat
        data = x_test_cv.copy()
        data['response'] = y_test_cv.copy()
        
        data['score'] = pred[:, 1].tolist()
        
        data = data.sort_values( 'score', ascending=False )
        
        # measuring at k metrics
        precision_at_k_list.append( precision_at_k( data, k ) )
        recall_at_k_list.append(recall_at_k( data, k ) )
        
    
    precision_at_k_mean, precision_at_k_std = np.round( np.mean( precision_at_k_list ), 3 ), np.round( np.std( precision_at_k_list ), 3 )
    recall_at_k_mean, recall_at_k_std = np.round( np.mean( recall_at_k_list ), 3 ), np.round( np.std( recall_at_k_list ), 3 )
   
    
    return pd.DataFrame({"Precision_at_k": "{} +/- {}".format(precision_at_k_mean, precision_at_k_std),
                         "Recall_at_k": "{} +/- {}".format(recall_at_k_mean, recall_at_k_std)}, index=[model_name])

# %%
jupyter_settings()
# Out:
# <style>.container { width:80% !important; }</style>

# %% [markdown]
# ## 0.1 Schema Query

# %%
# connecting to DB
conn, cursor = connect()

# nspname: name of the namespace
# pg_namespace: system catalogue table containing schema definitions

query_schema = """
    SELECT nspname
    FROM pg_catalog.pg_namespace
"""

cursor.execute(query_schema)
record = (cursor.fetchall())
print(record)
cursor.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13904/4065366229.py in <module>
#       1 # connecting to DB
# ----> 2 conn, cursor = connect()
#       3
#       4 # nspname: name of the namespace
#       5 # pg_namespace: system catalogue table containing schema definitions
#
# ~\AppData\Local\Temp/ipykernel_13904/664089208.py in connect()
#       4
#       5     # set up a connection to the postgres server.
# ----> 6     conn_string = ("host="+ creds.PGHOST +\
#       7                    " port="+ "5432" +\
#       8                    " dbname="+ creds.PGDATABASE +\
#
# AttributeError: module 'config' has no attribute 'PGHOST'

# %% [markdown]
# ## Table Query

# %%
#connecting to DB
conn, cursor = connect()

query_tables = """
    SELECT tablename
    FROM pg_tables
    WHERE schemaname ='pa004'
"""

cursor.execute(query_tables)
record = (cursor.fetchall())
print(record)
cursor.close()
conn.close()

# %% [markdown]
# ## Collect Data

# %% [markdown]
# ### Using psycopg2

# %%
# connecting to DB
conn, cursor = connect()

# the 'age > 44' is just an example to make the query faster
query_tables_users = """
    SELECT *
    FROM pa004.users u
    WHERE age > 44
"""

cursor.execute(query_tables_users)
record = (cursor.fetchall())
cursor.close()
conn.close()

# not good because it is necessary to enter columns names manually
# to improve this, we can make data collection using pandas
pd.DataFrame(record).head()

# %% [markdown]
# ###  Using pandas.io.sql

# %%
import pandas.io.sql as psql

# %%
conn, cursor = connect()

query_tables_users = """
    SELECT *
    FROM pa004.users u
"""

# the columns names are obtained when using pandas to collect data
display(psql.read_sql(query_tables_users, conn).head())

cursor.close()
conn.close()

# %% [markdown]
# ###  Loading Data with Pandas

# %%
conn, cursor = connect()

query_tables_users = """
    SELECT *
    FROM pa004.users u
"""

# the columns names are obtained when using pandas to collect data
display(pd.read_sql(query_tables_users, conn).head())

cursor.close()
conn.close()

# %% [markdown]
# ## Join all the tables

# %%
conn, cursor = connect()

query_tables_users = """
    SELECT *
    FROM pa004.users u inner join pa004.vehicle v on(u.id=v.id)
                       inner join pa004.insurance i on(u.id = i.id)
"""

# the columns names are obtained when using pandas to collect data
df_raw = pd.read_sql(query_tables_users, conn)

cursor.close()
conn.close()

# %%
# remove duplicate columns (i.e. the 'id' from vehicle and insurance tables)
df_raw = df_raw.loc[:,~df_raw.columns.duplicated()]
df_raw

# %% [markdown]
# ## Collect with pandas

# %%
df_raw = pd.read_csv('data/raw/train.csv')

# %%
df_raw.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  Response
# 0   1    Male   44                1         28.0                   0   > 2 Years            Yes         40454.0                  26.0      217         1
# 1   2    Male   76                1          3.0                   0    1-2 Year             No         33536.0                  26.0      183         0
# 2   3    Male   47                1         28.0                   0   > 2 Years            Yes         38294.0                  26.0       27         1
# 3   4    Male   21                1         11.0                   1    < 1 Year             No         28619.0                 152.0      203         0
# 4   5  Female   29                1         41.0                   1    < 1 Year             No         27496.0                 152.0       39         0

# %% [markdown]
# # 1.0 DESCRIÇÃO DOS DADOS

# %%
df1 = df_raw.copy()

# %% [markdown]
# ## Spliting to take a test dataset

# %%
X = df1.drop('Response', axis=1)
y = df1['Response'].copy()

x_training, x_test, y_training, y_test = ms.train_test_split( X, y, test_size=0.10, random_state=28 )

df1 = pd.concat( [x_training, y_training ], axis=1 )

# %%
df_test = pd.concat( [x_test, y_test ], axis=1 )

# %% [markdown]
# ### Checking Proportions

# %%
df_raw['Response'].value_counts(normalize=True)
# Out:
# 0    0.877437
# 1    0.122563
# Name: Response, dtype: float64

# %%
df1['response'].value_counts(normalize=True)
# Out:
# 0    0.877504
# 1    0.122496
# Name: response, dtype: float64

# %%
df_test['Response'].value_counts(normalize=True)
# Out:
# 0    0.876833
# 1    0.123167
# Name: Response, dtype: float64

# %% [markdown]
# ## Renaming Columns

# %%
cols_new = ['id', 'gender', 'age', 'driving_license', 'region_code',
       'previously_insured', 'vehicle_age', 'vehicle_damage', 'annual_premium',
       'policy_sales_channel', 'vintage', 'response']

df1.columns = cols_new

# %% [markdown]
# ## General Look

# %%
# Verificando características do DataFrame
df1.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 342998 entries, 289088 to 42241
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    342998 non-null  int64
#  1   gender                342998 non-null  object
#  2   age                   342998 non-null  int64
#  3   driving_license       342998 non-null  int64
#  4   region_code           342998 non-null  float64
#  5   previously_insured    342998 non-null  int64
#  6   vehicle_age           342998 non-null  object
#  7   vehicle_damage        342998 non-null  object
#  8   annual_premium        342998 non-null  float64
#  9   policy_sales_channel  342998 non-null  float64
#  10  vintage               342998 non-null  int64
#  11  response              342998 non-null  int64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 34.0+ MB

# %%
# Printando numero de linhas e colunas
print('Número de colunas: {}'.format(df1.shape[1]))
print('Número de linhas: {}'.format(df1.shape[0]))
# Out:
# Número de colunas: 12
# Número de linhas: 342998

# %% [markdown]
# ## Numerical Statistics

# %%
# Estatistica Descritiva
df_statistics = df1[['age', 'annual_premium', 'vintage', 'driving_license']]

# Central Tendency - mean, median
ct1 = pd.DataFrame( df_statistics.apply( np.mean ) ).T
ct2 = pd.DataFrame( df_statistics.apply( np.median ) ).T

# Dispersion - std, min, max, range, skew, kurtosis
d1 = pd.DataFrame( df_statistics.apply( np.std ) ).T
d2 = pd.DataFrame( df_statistics.apply( min ) ).T
d3 = pd.DataFrame( df_statistics.apply( max ) ).T
d4 = pd.DataFrame( df_statistics.apply( lambda x: x.max() - x.min() ) ).T
d5 = pd.DataFrame( df_statistics.apply( lambda x: x.skew() ) ).T
d6 = pd.DataFrame( df_statistics.apply( lambda x: x.kurtosis() ) ).T

# Concat
m = pd.concat( [d2, d3, d4, ct1, ct2, d1, d5, d6] ).T.reset_index()
m.columns = ['attributes', 'min', 'max', 'range', 'mean', 'median', 'std', 'skew', 'kurtosis']
m
# Out:
#         attributes     min       max     range          mean   median           std       skew    kurtosis
# 0              age    20.0      85.0      65.0     38.831031     36.0     15.512921   0.671382   -0.569692
# 1   annual_premium  2630.0  540165.0  537535.0  30550.040817  31661.0  17218.906921   1.787014   34.788193
# 2          vintage    10.0     299.0     289.0    154.386163    154.0     83.667518   0.001966   -1.201107
# 3  driving_license     0.0       1.0       1.0      0.997854      1.0      0.046273 -21.518273  461.038780

# %%
# Verificando o balanceamento da variável resposta
df_response = df1[['response', 'id']].groupby('response').count().reset_index().rename(columns={'id': 'total' })
df_response
# Out:
#    response   total
# 0         0  300982
# 1         1   42016

# %%
# Colocando em gráfico a variavel resposta
sns.barplot( data=df_response, x='response', y='total' );

# %% [markdown]
# # 2.0 FEATURE ENGINEERING

# %%
df2 = df1.copy()

# %% [markdown]
# ## 2.1 Mapa Mental de Hipóteses

# %%
Image('C:/Users/Pedro/repos/health_insurance_cross_sell/pa004_health_insurance_cross_sell/health_insurance_cross-sell/img/car_insurance.png')

# %% [markdown]
# ## 2.2 Criação das Hipóteses

# %% [markdown]
# ### 2.2.1 Hipóteses de Clientes

# %% [markdown]
# **1.** 100% dos clientes sem carteira de habilitação não aderem ao seguro.
#
# **2.** Clientes com mais dias associados tendem a aderir ao seguro.
#
# **3.** 100% dos clientes que ja tiveram o carro batido aderem ao seguro.
#
# **4.** Clientes mais velhos tendem a aderir ao seguro.
#
# **5.** Mulheres tendem a aderir ao seguro 30% mais que homens.

# %% [markdown]
# ### 2.2.1 Hipóteses de Localização

# %% [markdown]
# **1.** Clientes em zona rural aderem menos ao seguro.
#
# **2.** Clientes em cidades grandes aderem mais ao seguro.

# %% [markdown]
# ### 2.2.1 Hipóteses de Veiculo

# %% [markdown]
# **1.** Com veículo mais velho tendem a não aderir ao seguro.
#
# **2.** 100% dos clientes que ja tem seguro de carro não aderem ao seguro.

# %% [markdown]
# ## 2.3 Lista Final de Hipóteses

# %% [markdown]
# **1.** 100% dos clientes sem carteira de habilitação não aderem ao seguro.
#
# **2.** Clientes com mais dias associados tendem a aderir ao seguro.
#
# **3.** 100% dos clientes que ja tiveram o carro batido aderem ao seguro.
#
# **4.** Clientes mais velhos tendem a aderir ao seguro.
#
# **5.** Mulheres tendem a aderir ao seguro 30% mais que homens.
#
# **6.** Clientes em zona rural aderem menos ao seguro.
#
# **7.** Clientes em cidades grandes aderem mais ao seguro.
#
# **8.** Com veículo mais velho tendem a não aderir ao seguro.
#
# **9.** 100% dos clientes que ja tem seguro de carro não aderem ao seguro.

# %% [markdown]
# ## 2.4 Feature Engineering

# %%
# vehicle_Age
df2['vehicle_age'] = df2['vehicle_age'].apply( lambda x: 'below_1_year' if x == '< 1 Year' else 'between_1_2_year' if x == '1-2 Year' else 'over_2_years' )

# vehicle_damage
df2['vehicle_damage'] = df2['vehicle_damage'].apply( lambda x: 1 if x == 'Yes' else 0 )

# %%
df2['vehicle_damage'].value_counts()
# Out:
# 1    173323
# 0    169675
# Name: vehicle_damage, dtype: int64

# %% [markdown]
# # 3.0 ANÁLISE EXPLORATÓRIA DOS DADOS

# %%
df3 = df2.copy()

# %% [markdown]
# ## 3.1 Análise Univariada

# %% [markdown]
# ### 3.1.1 Variavel Resposta

# %%
sns.displot( df3['response'] );

# %% [markdown]
# ### 3.1.2 Varivavel Numérica

# %%
df_statistics['vehicle_damage'] = df3['vehicle_damage']
df_statistics.hist(bins=25);

# %% [markdown]
# ### 3.1.3 Varivavel Categórica

# %%
cat_attributes = df3.select_dtypes( exclude=['int64', 'float64', 'datetime64[ns]'] )
cat_attributes.columns

# %%
plt.subplot( 1, 2, 1 )
ax1 = sns.countplot( df3['gender'] );
for i in ax1.containers:
    ax1.bar_label(i,);
    
plt.subplot( 1, 2, 2 )
ax2 = sns.countplot( df3['vehicle_age'] );
for i in ax2.containers:
    ax2.bar_label(i,);

# %% [markdown]
# ## 3.2 Análise Bivariada

# %% [markdown]
# ### 1. 100% dos clientes sem carteira de habilitação não aderem ao seguro.
#     FALSA. Das 812 pessoas que não possuem carteira de motorista, 41 aceitaram o seguro: 5,05%

# %%
plt.subplot( 1, 2, 1 )
df3_aux1 = df3.loc[df3['driving_license']==1, :]
aux1 = df3_aux1[['driving_license', 'response', 'id']].groupby(['driving_license', 'response']).count().reset_index()
a = sns.barplot( data=aux1, x='driving_license', y='id', hue='response')
for i in a.containers:
    a.bar_label(i,);
    
plt.subplot( 1, 2, 2 )
df3_aux2 = df3.loc[df3['driving_license']==0, :]
aux1 = df3_aux2[['driving_license', 'response', 'id']].groupby(['driving_license', 'response']).count().reset_index()
b = sns.barplot( data=aux1, x='driving_license', y='id', hue='response')
for i in b.containers:
    b.bar_label(i,);

# %% [markdown]
# ### 2. Clientes com mais dias associados tendem a aderir ao seguro.
#     Falsa - Na média ambos que aceitaram ou recusaram tem a mesma quantidade de dias associados

# %%
aux1 = df3[['vintage', 'response']].groupby('response').mean().reset_index()
a = sns.barplot( data=aux1, x='response', y='vintage');
for i in a.containers:
    a.bar_label(i,);

# %% [markdown]
# ### **3.** 100% dos clientes que ja tiveram o carro batido aderem ao seguro.
#     Falsa - Das pessoas que ja bateram o carro 76,23% recusaram o seguro.

# %%
aux1 = df3[['vehicle_damage', 'response', 'id']].groupby(['response', 'vehicle_damage']).count().reset_index()
a = sns.barplot( data=aux1, x='vehicle_damage', y='id', hue='response');
for i in a.containers:
    a.bar_label(i,);

# %% [markdown]
# ### **4.** Clientes mais velhos tendem a aderir ao seguro.
#     Verdadeiro - Na média, clientes que aceitam o seguro são mais velhos.

# %%
plt.subplot(1, 2, 1)
aux1 = df3[['age', 'response']].groupby('response').mean().reset_index()
a = sns.barplot( data=aux1, x= 'response', y='age');
for i in a.containers:
    a.bar_label(i,);
    
plt.subplot(1, 2, 2)
sns.histplot( df3['age'] );

# %% [markdown]
# ### **5.** Mulheres tendem a aderir ao seguro 30% mais que homens.
#     Falsa - Apenas 10,39% das mulheres aceitaram o seguro. Enquanto 13,84% dos homens aceitaram.

# %%
aux1 = df3[['gender', 'response', 'id']].groupby(['response', 'gender']).count().reset_index()
a = sns.barplot( data=aux1, x= 'gender', y='id', hue='response');
for i in a.containers:
    a.bar_label(i,);

# %% [markdown]
# ### **6.** Clientes em zona rural aderem menos ao seguro.

# %% [markdown]
# ### **7.** Clientes em cidades grandes aderem mais ao seguro.

# %% [markdown]
# ### **8.** Clientes com veículo mais velho tendem a não aderir ao seguro.
#     Falsa - A maior taxa de conversão são os que tem o carro > 2 anos, com 29,37%. Seguido dos carros entre 1-2 anos com 17,38%.

# %%
aux1 = df3[['vehicle_age', 'response', 'id']].groupby(['response', 'vehicle_age']).count().reset_index()
a = sns.barplot( data=aux1, x='vehicle_age', y='id', hue='response');
for i in a.containers:
    a.bar_label(i,);

# %% [markdown]
# ### **9.** 100% dos clientes que ja tem seguro de carro não aderem ao seguro.
#     Falsa - 99,91% dos que ja possuem seguro não aderem ao novo seguro.

# %%
aux1 = df3[['previously_insured', 'response', 'id']].groupby(['response', 'previously_insured']).count().reset_index()
a = sns.barplot( data=aux1, x='previously_insured', y='id', hue='response');
for i in a.containers:
    a.bar_label(i,);

# %% [markdown]
# ## 3.1 Análise Multivariada

# %% [markdown]
# ### 3.1.1 Numerical Attributes

# %%
num_atributes = df3.select_dtypes( include=['int64', 'float64'] )
correlation = num_atributes.corr( method='pearson' )
sns.heatmap( correlation, annot=True );

# %% [markdown]
# ### 3.1.1 Categorical Attributes

# %%
# only categorical data
a = df3.select_dtypes( include='object' )
a.columns
# Out:
# Index(['gender', 'vehicle_age'], dtype='object')

# %%
# Calculate cramer V
a1 = cramer_v( a['gender'], a['gender'] )
a2 = cramer_v( a['gender'], a['vehicle_age'] )
a4 = cramer_v( a['vehicle_age'], a['gender'] )
a5 = cramer_v( a['vehicle_age'], a['vehicle_age'] )

# Final dataset
d = pd.DataFrame( {'gender': [a1, a2],
                    'vehicle_age': [a4, a5] } )
d = d.set_index( d.columns )
sns.heatmap( d, annot=True );

# %%
correlation = df_statistics.corr( method='pearson' )
sns.heatmap( correlation, annot=True );

# %% [markdown]
# # 4.0 DATA PREPARATION

# %%
df4= df3.copy()

# %% [markdown]
# ## Split into train and validation datasets

# %%
X = df3.drop('response', axis=1)
y = df3['response'].copy()

# %%
x_train, x_validation, y_train, y_validation = ms.train_test_split( X, y, test_size=0.20 )

df4 = pd.concat( [ x_train, y_train ], axis = 1 )

# %%
df4['response'].value_counts(normalize=True)
# Out:
# 0    0.877667
# 1    0.122333
# Name: response, dtype: float64

# %%
y_validation.value_counts(normalize=True)
# Out:
# 0    0.876851
# 1    0.123149
# Name: response, dtype: float64

# %% [markdown]
# ## Stardadization

# %%
ss = pp.StandardScaler()

# Annual Premium
df4['annual_premium'] = ss.fit_transform( df4[['annual_premium']].values )
pickle.dump( ss, open( 'C:/Users/Pedro/repos/health_insurance_cross_sell/pa004_health_insurance_cross_sell/health_insurance_cross-sell/src/features/annual_premium_scaler.pkl', 'wb' ) )

# %% [markdown]
# ## Rescaling

# %%
mms_age = pp.MinMaxScaler()
mms_vintage = pp.MinMaxScaler()

# Age
df4['age'] = mms_age.fit_transform( df4[['age']].values )
pickle.dump( mms_age, open('C:/Users/Pedro/repos/health_insurance_cross_sell/pa004_health_insurance_cross_sell/health_insurance_cross-sell/src/features/age_scaler.pkl', 'wb' ) )

# Vintage
df4['vintage'] = mms_vintage.fit_transform( df4[['vintage']].values )
pickle.dump( mms_vintage, open('C:/Users/Pedro/repos/health_insurance_cross_sell/pa004_health_insurance_cross_sell/health_insurance_cross-sell/src/features/vintage_scaler.pkl', 'wb') )

# %% [markdown]
# ## Encoder

# %%
# Gender - Target Encoding
target_encoding_gender = df4.groupby('gender')['response'].mean()
df4.loc[:, 'gender'] = df4['gender'].map( target_encoding_gender )
pickle.dump(target_encoding_gender, open('C:/Users/Pedro/repos/health_insurance_cross_sell/pa004_health_insurance_cross_sell/health_insurance_cross-sell/src/features/target_encode_gender_scaler.pkl', 'wb'  )  )

# Region Code - Target Encoding
target_encoding_region_code = df4.groupby('region_code')['response'].mean() 
df4.loc[:, 'region_code'] = df4['region_code'].map( target_encoding_region_code )
pickle.dump(target_encoding_region_code, open('C:/Users/Pedro/repos/health_insurance_cross_sell/pa004_health_insurance_cross_sell/health_insurance_cross-sell/src/features/target_encode_region_code_scaler.pkl', 'wb' ) )
 
# Vehicle Age - One Hot Encoding
df4 = pd.get_dummies( df4, prefix='vehicle_age', columns=['vehicle_age'] )

# Policy Sales Channel - Target Encoding / Frequency Encoding
fe_policy_sales_channel = df4.groupby('policy_sales_channel').size() / len( df4 )
df4.loc[:, 'policy_sales_channel'] = df4['policy_sales_channel'].map( fe_policy_sales_channel )
pickle.dump(fe_policy_sales_channel, open('C:/Users/Pedro/repos/health_insurance_cross_sell/pa004_health_insurance_cross_sell/health_insurance_cross-sell/src/features/fe_policy_sales_channel_scaler.pkl', 'wb'))

# %% [markdown]
# ## 4.1 Validation Preparation

# %%
# Gender
x_validation.loc[:, 'gender'] = x_validation.loc[:, 'gender'].map( target_encoding_gender )

# Age
x_validation.loc[:, 'age'] = mms_age.transform( x_validation[['age']].values )

# Region Code
x_validation.loc[:, 'region_code'] = x_validation.loc[:, 'region_code'].map( target_encoding_region_code )

# Vintage
x_validation.loc[:, 'vintage'] = mms_vintage.transform( x_validation[['vintage']].values )

# Annual Premium
x_validation.loc[:, 'annual_premium'] = ss.transform( x_validation[['annual_premium']].values )

# Vehicle Age
x_validation = pd.get_dummies( x_validation, prefix='vehicle_age', columns=['vehicle_age'] )

# Policy Sales Channel
x_validation.loc[:, 'policy_sales_channel'] = x_validation['policy_sales_channel'].map( fe_policy_sales_channel )

# fill NA - Conferir se tinha NA
x_validation = x_validation.fillna( 0 )

# %% [markdown]
# # 5.0 FEATURE SELECTION

# %% [markdown]
# ## 5.1 Features Importance

# %%
# Model Definition
forest = en.ExtraTreesClassifier( n_estimators=250, random_state=28, n_jobs=-1 )

# Data Preparation
x_train_n = df4.drop( ['id', 'response'], axis=1 )
y_train_n = y_train.values
forest.fit( x_train_n, y_train_n )
# Out:
# ExtraTreesClassifier(n_estimators=250, n_jobs=-1, random_state=28)

# %%
importances = forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in forest.estimators_], axis=0)
indices = np.argsort(importances)[::-1]

# Print Feature Ranking
print('Feature Importance:')
df = pd.DataFrame()
for i, j in zip( x_train_n, importances ):
    aux = pd.DataFrame( {'feature':i, 'importance':j}, index=[0] )
    df = pd.concat( [df, aux], axis=0 )
    
print(df.sort_values('importance', ascending=False))
# Out:
# Feature Importance:
#                         feature  importance
# 0                       vintage    0.270994
# 0                annual_premium    0.242444
# 0                           age    0.169601
# 0                   region_code    0.105500
# 0                vehicle_damage    0.074548
# 0          policy_sales_channel    0.060100
# 0            previously_insured    0.048687
# 0      vehicle_age_below_1_year    0.013631
# 0  vehicle_age_between_1_2_year    0.006173
# 0                        gender    0.005132
# 0      vehicle_age_over_2_years    0.002712
# 0               driving_license    0.000479

# %% [markdown]
# # 6.0 MACHINE LEARNING

# %%
cols_selected = ['vintage', 'annual_premium', 'age', 'region_code', 'vehicle_damage', 'policy_sales_channel', 'previously_insured']

x_train = df4[cols_selected]
x_val = x_validation[cols_selected]
y_val = y_validation.copy()

# %% [markdown]
# ## 6.1 KNN

# %%
# Model Definition
knn_model = nh.KNeighborsClassifier( n_neighbors=7 )

# Model Training
knn_model.fit( x_train, y_train )

# Model Prediction - Poder de Generalização
yhat_knn = knn_model.predict_proba( x_val )

# Acumulative Gain
fig, axs = plt.subplots(ncols=2, figsize=(18,10))
skplt.metrics.plot_cumulative_gain( y_val, yhat_knn, ax=axs[0], title='Cumulative Gains Curve')
skplt.metrics.plot_lift_curve( y_val, yhat_knn, ax=axs[1], title='Lift Curve' )
# Out:
# <AxesSubplot:title={'center':'Lift Curve'}, xlabel='Percentage of sample', ylabel='Lift'>

# %%
knn_metrics = at_k_metrics( 'KNN', x_val, y_val, yhat_knn, k=20000 )
knn_metrics
# Out:
#     Precision_at_k Recall_at_k
# KNN          0.284       0.673

# %% [markdown]
# ## 6.2 Logistic Regression

# %%
# Model Definition
lr_model = lm.LogisticRegression( random_state=42 )

# Model Training
lr_model.fit( x_train, y_train )

# Model Prediction
yhat_lr = lr_model.predict_proba( x_val )

fig, axs = plt.subplots(ncols=2, figsize=(18,10))
skplt.metrics.plot_cumulative_gain( y_val, yhat_lr, ax=axs[0], title='Cumulative Gains Curve')
skplt.metrics.plot_lift_curve( y_val, yhat_lr, ax=axs[1], title='Lift Curve' )
# Out:
# <AxesSubplot:title={'center':'Lift Curve'}, xlabel='Percentage of sample', ylabel='Lift'>

# %%
lr_metrics = at_k_metrics( 'Logistic Regression', x_val, y_val, yhat_lr, k=20000 )
lr_metrics
# Out:
#                     Precision_at_k Recall_at_k
# Logistic Regression          0.284       0.672

# %% [markdown]
# ## 6.3 Extra Trees

# %%
# Model Definition
et_model = en.ExtraTreesClassifier( n_estimators=1000, n_jobs=-1, random_state=42 )

# Model Training
et_model.fit( x_train, y_train )

# Model Prediction - Poder de Generalização
yhat_et = et_model.predict_proba( x_val )

fig, axs = plt.subplots(ncols=2, figsize=(18,10))
skplt.metrics.plot_cumulative_gain( y_val, yhat_et, ax=axs[0], title='Cumulative Gains Curve')
skplt.metrics.plot_lift_curve( y_val, yhat_et, ax=axs[1], title='Lift Curve' )
# Out:
# <AxesSubplot:title={'center':'Lift Curve'}, xlabel='Percentage of sample', ylabel='Lift'>

# %%
et_metrics = at_k_metrics( 'Extra Trees', x_validation, y_validation, yhat_et, k=20000 )
et_metrics
# Out:
#             Precision_at_k Recall_at_k
# Extra Trees          0.298       0.705

# %% [markdown]
# ## 6.4 Random Forest

# %%
# model definition
rf = en.RandomForestClassifier( n_estimators=1000, n_jobs=-1, random_state=42 ) 

# model training
rf.fit( x_train, y_train )

# model prediction
yhat_rf = rf.predict_proba( x_val )

fig, axs = plt.subplots(ncols=2, figsize=(18,10))
skplt.metrics.plot_cumulative_gain( y_val, yhat_rf, ax=axs[0], title='Cumulative Gains Curve')
skplt.metrics.plot_lift_curve( y_val, yhat_rf, ax=axs[1], title='Lift Curve' )
# Out:
# <AxesSubplot:title={'center':'Lift Curve'}, xlabel='Percentage of sample', ylabel='Lift'>

# %%
rf_metrics = at_k_metrics( 'Random Forest', x_validation, y_validation, yhat_rf, k=20000 )
rf_metrics
# Out:
#               Precision_at_k Recall_at_k
# Random Forest          0.301       0.712

# %% [markdown]
# ## 6.5 XGBoost

# %%
xgb_model = xgb.XGBClassifier( objective='binary:logistic', eval_metrics='error' )

xgb_model.fit( x_train, y_train )

yhat_xgb = xgb_model.predict_proba( x_val )

fig, axs = plt.subplots(ncols=2, figsize=(18,10))
skplt.metrics.plot_cumulative_gain( y_val, yhat_xgb, ax=axs[0], title='Cumulative Gains Curve');
skplt.metrics.plot_lift_curve( y_val, yhat_xgb, ax=axs[1], title='Lift Curve' );
# Out:
# [09:44:24] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "eval_metrics" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.

# %%
xgb_metrics = at_k_metrics( 'XGBoost', x_validation, y_validation, yhat_xgb, k=20000 )
xgb_metrics
# Out:
#         Precision_at_k Recall_at_k
# XGBoost          0.321        0.76

# %% [markdown]
# ## 6.6 Light Gradient Boost Machine

# %%
lgbm_model = LGBMClassifier()

lgbm_model.fit(x_train, y_train)

yhat_lgbm = lgbm_model.predict_proba( x_val )

fig, axs = plt.subplots(ncols=2, figsize=(18,10))
skplt.metrics.plot_cumulative_gain( y_val, yhat_lgbm, ax=axs[0], title='Cumulative Gains Curve');
skplt.metrics.plot_lift_curve( y_val, yhat_lgbm, ax=axs[1], title='Lift Curve' );

# %%
lgbm_metrics = at_k_metrics( 'Light Gradient', x_validation, y_validation, yhat_lgbm, k=20000 )
lgbm_metrics
# Out:
#                Precision_at_k Recall_at_k
# Light Gradient          0.324       0.768

# %% [markdown]
# ## Metrics Resume

# %%
metrics = pd.concat([ knn_metrics, lr_metrics, et_metrics, rf_metrics, xgb_metrics, lgbm_metrics] )
metrics.sort_values('Precision_at_k', ascending=False)
# Out:
#                     Precision_at_k Recall_at_k
# Light Gradient               0.324       0.768
# XGBoost                      0.321        0.76
# Random Forest                0.301       0.712
# Extra Trees                  0.298       0.705
# KNN                          0.284       0.673
# Logistic Regression          0.284       0.672

# %% [markdown]
# # 7.0 CROSS VALIDATION

# %% [markdown]
# ## Cross Validation

# %%
warnings.filterwarnings( 'ignore' )

# %%
#knn_model_cv = cross_validation( 'KNN', knn_model, x_train, y_train )
#lr_model_cv = cross_validation( 'Logistic Regression', lr_model, x_train, y_train )
#rf_model_cv = cross_validation( 'Random Forest', rf, x_train, y_train )
#et_model_cv = cross_validation( 'Extra Trees', et_model, x_train, y_train )
#xgb_model_cv = cross_validation( 'XGBoost', xgb_model, x_train, y_train )
#lgbm_model_cv = cross_validation( 'Light Gradient', lgbm_model, x_train, y_train )
# Out:
# [10:01:44] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "eval_metrics" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [10:01:53] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "eval_metrics" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [10:02:02] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "eval_metrics" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [10:02:11] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "eval_metrics" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [10:02:20] WARNING: C:/Users/administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "eval_metrics" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.

# %% [markdown]
# ## Models Results

# %%
results = pd.concat( [knn_model_cv, lr_model_cv, rf_model_cv, et_model_cv, xgb_model_cv, lgbm_model_cv] )

# %%
results.sort_values( 'Precision_at_k', ascending=False )
# Out:
#                       Precision_at_k      Recall_at_k
# Light Gradient       0.296 +/- 0.001  0.881 +/- 0.004
# XGBoost              0.295 +/- 0.001   0.88 +/- 0.004
# Random Forest        0.284 +/- 0.002  0.847 +/- 0.005
# Extra Trees           0.28 +/- 0.001  0.834 +/- 0.004
# Logistic Regression  0.273 +/- 0.001  0.812 +/- 0.002
# KNN                    0.268 +/- 0.0  0.799 +/- 0.002

# %% [markdown]
# # 8.0 HYPER-PARAMETER FINE TUNING

# %%
warnings.filterwarnings( 'ignore' )

# %%
param = {'num_leaves':[35, 50, 80, 110],
         'max_depth':[3, 5, 7, 9],
         'min_split_gain':[0.001, 0.01, 0.1],
         'min_child_weight':[10, 30, 40, 50],
         'colssample_bytree':[0.1, 1],
         'learning_rate':[0.01, 0.05, 0.1]
        }

MAX_EVAL = 7

# %%
final_result = pd.DataFrame()

for i in range ( MAX_EVAL ):
    # choose values parameters randomly
    hp = {k: random.sample( v, 1 )[0] for k, v in param.items()}
    print(hp)

    # model
    model_lgbm = LGBMClassifier( objective='binary',
                              num_leaves=hp['num_leaves'],
                              max_depth=hp['max_depth'],
                              min_split_gain=hp['min_split_gain'],
                              min_child_weight=hp['min_child_weight'],
                              colssample_bytree=hp['colssample_bytree'],
                              learning_rate=hp['learning_rate'] )


    # performance
    result = cross_validation( 'Light Gradient Classifier', lgbm_model, x_train, y_train )
    final_result = pd.concat( [final_result, result] )
    
final_result
# Out:
# {'num_leaves': 50, 'max_depth': 9, 'min_split_gain': 0.001, 'min_child_weight': 50, 'colssample_bytree': 0.1, 'learning_rate': 0.05}
# {'num_leaves': 35, 'max_depth': 7, 'min_split_gain': 0.01, 'min_child_weight': 10, 'colssample_bytree': 1, 'learning_rate': 0.05}
# {'num_leaves': 50, 'max_depth': 3, 'min_split_gain': 0.01, 'min_child_weight': 50, 'colssample_bytree': 0.1, 'learning_rate': 0.05}
# {'num_leaves': 35, 'max_depth': 7, 'min_split_gain': 0.01, 'min_child_weight': 10, 'colssample_bytree': 1, 'learning_rate': 0.05}
# {'num_leaves': 35, 'max_depth': 9, 'min_split_gain': 0.001, 'min_child_weight': 50, 'colssample_bytree': 1, 'learning_rate': 0.05}
# {'num_leaves': 35, 'max_depth': 9, 'min_split_gain': 0.01, 'min_child_weight': 40, 'colssample_bytree': 0.1, 'learning_rate': 0.05}
# {'num_leaves': 110, 'max_depth': 3, 'min_split_gain': 0.1, 'min_child_weight': 50, 'colssample_bytree': 1, 'learning_rate': 0.1}
#                             Precision_at_k      Recall_at_k
# Light Gradient Classifier  0.296 +/- 0.001  0.881 +/- 0.004
# Light Gradient Classifier  0.296 +/- 0.001  0.881 +/- 0.004
# Light Gradient Classifier  0.296 +/- 0.001  0.881 +/- 0.004
# Light Gradient Classifier  0.296 +/- 0.001  0.881 +/- 0.004
# Light Gradient Classifier  0.296 +/- 0.001  0.881 +/- 0.004
# Light Gradient Classifier  0.296 +/- 0.001  0.881 +/- 0.004
# Light Gradient Classifier  0.296 +/- 0.001  0.881 +/- 0.004

# %%
# model_definition
lgbm_model_tuned = LGBMClassifier( objective='binary',
                              num_leaves=35,
                              max_depth=7,
                              min_split_gain=0.01,
                              min_child_weight=10,
                              colsample_bytree=1
                              )

# Model training
lgbm_model_tuned.fit(x_train, y_train)


yhat_lgbm_tuned = lgbm_model_tuned.predict_proba( x_val )

# %%
lgbm_metrics_tuned = at_k_metrics( 'Light Gradient', x_val, y_val, yhat_lgbm_tuned, k=20000 )
lgbm_metrics_tuned
# Out:
#                Precision_at_k Recall_at_k
# Light Gradient          0.324       0.768

# %%
fig, axs = plt.subplots(ncols=2, figsize=(18,10))
skplt.metrics.plot_cumulative_gain( y_val, yhat_lgbm_tuned, ax=axs[0], title='Cumulative Gains Curve');
skplt.metrics.plot_lift_curve( y_val, yhat_lgbm_tuned, ax=axs[1], title='Lift Curve' );

# %% [markdown]
# # 9.0 TESTING MODEL

# %%
df1_test = df_test.copy()

# %% [markdown]
# ## Renaming Columns

# %%
df1_test.columns = cols_new
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8364\1351405862.py in <module>
# ----> 1 df1_test.columns = cols_new
#       2 df1_test.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5586         try:
#    5587             object.__getattribute__(self, name)
# -> 5588             return object.__setattr__(self, name, value)
#    5589         except AttributeError:
#    5590             pass
#
# ~\anaconda3\lib\site-packages\pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     767     def _set_axis(self, axis: int, labels: Index) -> None:
#     768         labels = ensure_index(labels)
# --> 769         self._mgr.set_axis(axis, labels)
#     770         self._clear_item_cache()
#     771
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in set_axis(self, axis, new_labels)
#     212     def set_axis(self, axis: int, new_labels: Index) -> None:
#     213         # Caller is responsible for ensuring we have an Index object.
# --> 214         self._validate_set_axis(axis, new_labels)
#     215         self.axes[axis] = new_labels
#     216
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\base.py in _validate_set_axis(self, axis, new_labels)
#      67
#      68         elif new_len != old_len:
# ---> 69             raise ValueError(
#      70                 f"Length mismatch: Expected axis has {old_len} elements, new "
#      71                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 14 elements, new values have 12 elements

# %% [markdown]
# ## Feature Engineering

# %%
# vehicle_Age
df1_test['vehicle_age'] = df1_test['vehicle_age'].apply( lambda x: 'below_1_year' if x == '< 1 Year' else 'between_1_2_year' if x == '1-2 Year' else 'over_2_years' )

# vehicle_damage
df1_test['vehicle_damage'] = df1_test['vehicle_damage'].apply( lambda x: 1 if x == 'Yes' else 0 )

# %% [markdown]
# ## Data Preparation

# %%
# Gender
df1_test.loc[:, 'gender'] = df1_test.loc[:, 'gender'].map( target_encoding_gender )

# Age
df1_test.loc[:, 'age'] = mms_age.transform( df1_test[['age']].values )

# Region Code
df1_test.loc[:, 'region_code'] = df1_test.loc[:, 'region_code'].map( target_encoding_region_code )

# Vintage
df1_test.loc[:, 'vintage'] = mms_vintage.transform( df1_test[['vintage']].values )

# Annual Premium
df1_test.loc[:, 'annual_premium'] = ss.transform( df1_test[['annual_premium']].values )

# Vehicle Age
df1_test = pd.get_dummies( df1_test, prefix='vehicle_age', columns=['vehicle_age'] )

# Policy Sales Channel
df1_test.loc[:, 'policy_sales_channel'] = df1_test['policy_sales_channel'].map( fe_policy_sales_channel )

# fill NA - Conferir se tinha NA
df1_test = df1_test.fillna( 0 )

# %% [markdown]
# ## Testing Generalize

# %%
df2_test = df1_test[cols_selected]

# %%
yhat_test = lgbm_model_tuned.predict_proba( df2_test )

# %%
lgbm_metrics_tuned = at_k_metrics( 'Light Gradient Tuned', df2_test, y_test, yhat_test, k=12000 )
lgbm_metrics_tuned
# Out:
#                      Precision_at_k Recall_at_k
# Light Gradient Tuned          0.316       0.808

# %%
fig, axs = plt.subplots(ncols=2, figsize=(18,10))
skplt.metrics.plot_cumulative_gain( y_test, yhat_test, ax=axs[0], title='Cumulative Gains Curve');
skplt.metrics.plot_lift_curve( y_test, yhat_test, ax=axs[1], title='Lift Curve' );

# %% [markdown]
# ## Join Results into Original Test Data

# %%
df3_test = df_test.copy()

# %%
# Join Score into the Test Dataset
df3_test['score'] = yhat_test[:, 1].tolist()

# %%
df3_test = df3_test.sort_values('score', ascending=False).reset_index(drop=True)

# %%
df3_test.head(20)
# Out:
#         id  Gender  Age  Driving_License  Region_Code  Previously_Insured Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  Response     score
# 0    80083    Male   34                1         10.0                   0    1-2 Year            Yes         29231.0                 124.0      281         1  0.592165
# 1   287666    Male   30                1         11.0                   0    < 1 Year            Yes         18338.0                 124.0      238         1  0.590982
# 2   226812    Male   33                1         11.0                   0    < 1 Year            Yes         19444.0                 124.0      240         0  0.563432
# 3    51771    Male   33                1         29.0                   0    1-2 Year            Yes         19840.0                  26.0      247         1  0.548532
# 4   194341  Female   29                1         41.0                   0    1-2 Year            Yes         37919.0                 155.0      191         1  0.540965
# 5   374924    Male   38                1         11.0                   0    1-2 Year            Yes         28417.0                 155.0       32         0  0.532353
# 6   103557    Male   33                1         18.0                   0    < 1 Year            Yes         22213.0                 124.0      247         0  0.530674
# 7   203714    Male   32                1         10.0                   0   > 2 Years            Yes         23362.0                  26.0      287         0  0.530476
# 8   373239    Male   29                1         41.0                   0    1-2 Year            Yes         22128.0                 124.0      241         1  0.527745
# 9   320305    Male   29                1         29.0                   0    1-2 Year            Yes         29412.0                 124.0       22         1  0.526477
# 10  251803  Female   32                1         11.0                   0    < 1 Year            Yes         29057.0                 124.0      256         0  0.524595
# 11   70543  Female   33                1          8.0                   0    1-2 Year            Yes         31244.0                 155.0      118         0  0.518885
# 12  247361  Female   34                1         11.0                   0    1-2 Year            Yes         22131.0                 124.0       16         0  0.516938
# 13  190414  Female   34                1         11.0                   0    1-2 Year            Yes         37280.0                 124.0      261         1  0.507205
# 14  300239    Male   29                1         11.0                   0    1-2 Year            Yes         33373.0                 157.0      194         1  0.506618
# 15  329811    Male   37                1         41.0                   0    1-2 Year            Yes         26192.0                 155.0      235         1  0.506322
# 16   68956  Female   28                1         21.0                   0    1-2 Year            Yes         29664.0                 155.0       60         0  0.504454
# 17  339703  Female   38                1         41.0                   0    1-2 Year            Yes         19782.0                 155.0      154         1  0.503150
# 18   62226  Female   33                1         11.0                   0    1-2 Year            Yes         35200.0                 124.0      142         0  0.500943
# 19  236797  Female   32                1         35.0                   0    1-2 Year            Yes         24184.0                 124.0      194         0  0.500244

# %% [markdown]
# # 10.0 BUSINESS PERFORMANCE

# %% [markdown]
# ## 10.1 Main Insights

# %% [markdown]
#  - **Customers who have already crashed their car have a higher conversion rate of 23,77%**
#
# Vehicle Damage   | Interested in vehicle insurance | Not interested in vehicle insurance
# :--------- | :------ | :------
# Yes   | 23,77% | 76,23%
# No | 	0,52% | 99,48%
#
#
#  - **Customers with older cars have a higher conversion rate**
#
# Vehicle Age   | Interested in vehicle insurance | Not interested in vehicle insurance
# :--------- | :------ | :------
# Below 1 year | 4,37% | 95,63%
# Between 1 and 2 years | 	17,38% | 82,62%
# Above 2 years | 	29,37% | 70,63%
#
#
# - **Customers between 35 - 50 years old have more interest in vehicle insurance**

# %% [markdown]
# ## 10.2 What percentage of interested clients will the sales team be able to reach by making 20.000 calss?

# %% [markdown]
# - Reminding that our Real Test Dataset has 127.038 clients, and the Recall of our Model is 0.468, with the same proportion the sales team will reach 46,80% of interested clients

# %% [markdown]
# ## 10.3 And if we raise to 40.000 calls, what percentage will reach?

# %% [markdown]
# - 40.000 calls is about 31,50% of our test Data. So, if we made 40.000 calls we will reach about 80,80% according to our model

# %% [markdown]
# # 11.0 DEPLOY TO PRODUCTION

# %%
pickle.dump( lgbm_model_tuned, open('models/model_lgbm_tuned.pkl', 'wb') )

# %% [markdown]
# ## 11.1 Health Insurance Class

# %%
import pickle
import pandas as pd


class HealthInsurance(object):

    def __init__( self ):  
        self.homepath = 'C:/Users/Pedro/repos/health_insurance_cross_sell/pa004_health_insurance_cross_sell/health_insurance_cross-sell/'
        self.age_scaler                  = pickle.load( open(self.homepath + 'src/features/age_scaler.pkl', 'rb') )
        self.annual_premium_scaler       = pickle.load( open(self.homepath + 'src/features/annual_premium_scaler.pkl', 'rb') )
        self.policy_sales_channel_scaler = pickle.load( open(self.homepath + 'src/features/fe_policy_sales_channel_scaler.pkl', 'rb') )
        self.gender_scaler               = pickle.load( open(self.homepath + 'src/features/target_encode_gender_scaler.pkl', 'rb') )
        self.region_code_scaler          = pickle.load( open(self.homepath + 'src/features/target_encode_region_code_scaler.pkl', 'rb') )
        self.vintage_scaler              = pickle.load( open(self.homepath + 'src/features/vintage_scaler.pkl', 'rb') )
        
        
        
    def data_cleaning(self, data):
        
        cols_new = ['id', 'gender', 'age', 'driving_license', 'region_code',
                    'previously_insured', 'vehicle_age', 'vehicle_damage', 
                    'annual_premium', 'policy_sales_channel', 'vintage', 'response']

        data.columns = cols_new
        
        return data
    
    
    def feature_engineering(self, data):
        
        # vehicle_Age
        data['vehicle_age'] = data['vehicle_age'].apply( lambda x: 'below_1_year' if x == '< 1 Year' else 'between_1_2_year' if x == '1-2 Year' else 'over_2_years' )

        # vehicle_damage
        data['vehicle_damage'] = data['vehicle_damage'].apply( lambda x: 1 if x == 'Yes' else 0 )
        
        return data
    
    
    def data_preparation(self, data):
        
        # Annual Premium
        data['annual_premium'] = self.annual_premium_scaler.transform( data[['annual_premium']].values )
        
        # Age
        data['age'] = self.age_scaler.transform( data[['age']].values )
        
        # Vintage
        data['vintage'] = self.vintage_scaler.transform( data[['vintage']].values )
        
        # Gender 
        data.loc[:, 'gender'] = data['gender'].map( self.gender_scaler )
        
        # Region Code 
        data.loc[:, 'region_code'] = data['region_code'].map( self.region_code_scaler )
        
        # Vehicle Age 
        data = pd.get_dummies( data, prefix='vehicle_age', columns=['vehicle_age'] )
        
        # Policy Sales Channel - Target Encoding / Frequency Encoding
        data.loc[:, 'policy_sales_channel'] = data['policy_sales_channel'].map( self.policy_sales_channel_scaler )
        
        
        # Best Features       
        cols_selected = ['vintage', 'annual_premium', 'age', 'region_code', 'vehicle_damage', 'policy_sales_channel', 'previously_insured']
        
        return data[ cols_selected ] 
    
    
    def get_prediction(self, model, original_data, test_data):
        # model prediciton
        pred = model.predict_proba(test_data)

        # creating a prediction dataframe of the predict_proba (class 0 and 1 predictions)
        table_proba = pd.DataFrame(pred)

        # join prediction into original data
        original_data['Score'] = table_proba[1]

        original_data.sort_values('Score', ascending=False, inplace=True)

        return original_data.to_json(orient='records', date_format='iso')

# %% [markdown]
# ## 11.2 API Handler

# %%
import pickle
import pandas as pd
from flask import Flask, request, Response
from healthinsurance.HealthInsurance import HealthInsurance



# Loading Model
path = 'C:/Users/Pedro/repos/health_insurance_cross_sell/pa004_health_insurance_cross_sell/health_insurance_cross-sell/'
model = pickle.load( open(path + 'models/model_lgbm_tuned.pkl', 'rb' ) )

# Initialize API
app = Flask(__name__)

@app.route( '/healthinsurance/predict',  methods=['POST'] )

def health_insurance_predict():
    test_json = request.get_json()

    if test_json:
        if isinstance(test_json, dict):  # unique row
            test_raw = pd.DataFrame(test_json, index=[0])

        else:  # multiple rows
            test_raw = pd.DataFrame(test_json, columns=test_json[0].keys())

        test_raw_copy = test_raw.copy()

        # instantiate HealthInsurance class
        pipeline = HealthInsurance()

        # data cleaning
        df1 = pipeline.data_cleaning(test_raw)
        print('apos df1')
        print(test_raw.head())
        print(test_raw.head().values)

        # feature engineering
        df2 = pipeline.feature_engineering(df1)
        print('apos df2')
        print(test_raw.head())
        print(test_raw.head().values)

        # data preparation
        df3 = pipeline.data_preparation(df2)
        print('apos df3')
        print(test_raw.head())
        print(test_raw.head().values)

        # prediction
        df_response = pipeline.get_prediction(model, test_raw_copy, df3)

        return df_response

    else:
        return Response('{}', status=200, mimetype='application/json')
    
if __name__ == '__main__':
    app.run( '192.168.15.59')

# %% [markdown]
# ## 10.3 API Tester

# %%
import requests

# %%
# Loading DataSet
#df_test = x_validation
#df_test['response'] = y_validation

# loading dataset
df_test = pd.read_csv('data/test.csv')
data = json.dumps(df_test.to_dict(orient = 'records'))

# %%
df_test.columns
# Out:
# Index(['id', 'Gender', 'Age', 'Driving_License', 'Region_Code',
#        'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage', 'Annual_Premium',
#        'Policy_Sales_Channel', 'Vintage'],
#       dtype='object')

# %%
data= json.dumps( df_test.to_dict( orient='records' ) )

# %%
# API Call
#url = 'http://192.168.15.59:5000/healthinsurance/predict'
url = 'https://health-insurance-cross-sale.herokuapp.com/healthinsurance/predict'

header = {'Content-type': 'application/json' }

r = requests.post( url, data=data, headers=header )
print( 'Status Code {}'.format( r.status_code ) )
# Out:
# Status Code 200

# %%
d1 = pd.DataFrame( r.json(), columns=r.json()[0].keys() )

# %%
d1.sort_values( 'Score', ascending=False )
# Out:
#             id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0       503821    Male   35                1         38.0                   0
# 1       474441    Male   33                1         41.0                   0
# 2       497871  Female   41                1         10.0                   0
# 3       488476    Male   31                1         49.0                   0
# 4       385213  Female   30                1         41.0                   0
# ...        ...     ...  ...              ...          ...                 ...
# 127032  387521    Male   53                1         28.0                   1
# 127033  485430  Female   23                1         50.0                   1
# 127034  480763  Female   22                1         31.0                   1
# 127035  474545  Female   23                1         31.0                   1
# 127036  417862    Male   65                1         28.0                   1
#
#        Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  \
# 0         1-2 Year            Yes         17579.0                 154.0
# 1         < 1 Year            Yes         20153.0                 155.0
# 2         1-2 Year            Yes         23307.0                 157.0
# 3         1-2 Year            Yes         26155.0                 155.0
# 4         1-2 Year            Yes         32660.0                 155.0
# ...            ...            ...             ...                   ...
# 127032    1-2 Year             No         44719.0                 139.0
# 127033    < 1 Year             No         44459.0                 152.0
# 127034    < 1 Year             No          2630.0                 152.0
# 127035    < 1 Year             No          2630.0                 152.0
# 127036    1-2 Year             No         45479.0                 139.0
#
#         Vintage     Score
# 0            43  0.583284
# 1            58  0.564965
# 2           299  0.563101
# 3            94  0.555526
# 4           102  0.554887
# ...         ...       ...
# 127032       40  0.000006
# 127033       41  0.000005
# 127034      298  0.000005
# 127035      291  0.000005
# 127036       12  0.000005
#
# [127037 rows x 12 columns]

# %% [markdown]
# # Further considerations

# %% [markdown]
# For future learning to rank problems or new CRISP rounds, consider training these models:
#
# - Balanced Bagging Classifier;
# - Easy Ensemble Classifier;
# - Random Under Sampler Classifier;
# - Stochastic Gradient Descent Classifier;
